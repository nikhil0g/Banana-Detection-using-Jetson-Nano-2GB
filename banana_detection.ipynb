# %%
#clone YOLOv5 and 
#!git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images
# Out:
# /home/nikhil/self_Project/yolov5
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
os.environ["DATASET_DIRECTORY"] = "../banana_datasets"

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="KnO1HFUawybkKzxGovmP")
project = rf.workspace().project("banana_detection-z0bjh")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ../banana_datasets/banana_detection-1 in yolov5pytorch:: 100%|██████████| 252/252 [00:00<00:00, 5633.45it/s]

# %%
#!python train.py --img 416 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights //home/nikhil/Downloads/banana.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['//home/nikhil/Downloads/banana.pt'], source=/home/nikhil/self_Project/banana_datasets/banana_detection-1/test/images, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/5 /home/nikhil/self_Project/banana_datasets/banana_detection-1/test/images/42banana_png.rf.37dfc3409a8b22d3793fc085f23f7456.jpg: 416x416 1 fresh-banana, Done. (0.222s)
# image 2/5 /home/nikhil/self_Project/banana_datasets/banana_detection-1/test/images/44banana_png.rf.c567786691e543505159fd50a8d9513e.jpg: 416x416 1 fresh-banana, Done. (0.142s)
# ...

# %%
# !python detect.py --weights //home/nikhil/Downloads/banana.pt --img 416 --conf 0.1 --source banana.mp4
# Out:
# detect: weights=['//home/nikhil/Downloads/banana.pt'], source=banana.mp4, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2782) /home/nikhil/self_Project/yolov5/banana.mp4: 256x416 Done. (0.099s)
# video 1/1 (2/2782) /home/nikhil/self_Project/yolov5/banana.mp4: 256x416 Done. (0.082s)
# video 1/1 (3/2782) /home/nikhil/self_Project/yolov5/banana.mp4: 256x416 Done. (0.083s)
# video 1/1 (4/2782) /home/nikhil/self_Project/yolov5/banana.mp4: 256x416 Done. (0.067s)
# ...
